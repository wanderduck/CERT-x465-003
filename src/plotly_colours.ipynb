# %%
pokes_colors = {
	'normal': '#A8A77A',
	'fire': '#EE8130',
	'water': '#6390F0',
	'electric': '#F7D02C',
	'grass': '#7AC74C',
	'ice': '#96D9D6',
	'fighting': '#C22E28',
	'poison': '#A33EA1',
	'ground': '#E2BF65',
	'flying': '#A98FF3',
	'psychic': '#F95587',
	'bug': '#A6B91A',
	'rock': '#B6A136',
	'ghost': '#735797',
	'dragon': '#6F35FC',
	'dark': '#705746',
	'steel': '#B7B7CE',
	'fairy': '#D685AD',
};

# %%
grass = pokes.loc[pokes['Type 1'] == 'Grass']
fire = pokes.loc[pokes['Type 1'] == 'Fire']
water = pokes.loc[pokes['Type 1'] == 'Water']
bug = pokes.loc[pokes['Type 1'] == 'Bug']
normal = pokes.loc[pokes['Type 1'] == 'Normal']
poison = pokes.loc[pokes['Type 1'] == 'Poison']
electric = pokes.loc[pokes['Type 1'] == 'Electric']
ground = pokes.loc[pokes['Type 1'] == 'Ground']
fairy = pokes.loc[pokes['Type 1'] == 'Fairy']
fighting = pokes.loc[pokes['Type 1'] == 'Fighting']
psychic = pokes.loc[pokes['Type 1'] == 'Psychic']
rock = pokes.loc[pokes['Type 1'] == 'Rock']
ghost = pokes.loc[pokes['Type 1'] == 'Ghost']
ice = pokes.loc[pokes['Type 1'] == 'Ice']
dragon = pokes.loc[pokes['Type 1'] == 'Dragon']
dark = pokes.loc[pokes['Type 1'] == 'Dark']
steel = pokes.loc[pokes['Type 1'] == 'Steel']
flying = pokes.loc[pokes['Type 1'] == 'Flying']

# %%
grass2 = pokes.loc[pokes['Type 2'] == 'Grass']
fire2 = pokes.loc[pokes['Type 2'] == 'Fire']
water2 = pokes.loc[pokes['Type 2'] == 'Water']
bug2 = pokes.loc[pokes['Type 2'] == 'Bug']
normal2 = pokes.loc[pokes['Type 2'] == 'Normal']
poison2 = pokes.loc[pokes['Type 2'] == 'Poison']
electric2 = pokes.loc[pokes['Type 2'] == 'Electric']
ground2 = pokes.loc[pokes['Type 2'] == 'Ground']
fairy2 = pokes.loc[pokes['Type 2'] == 'Fairy']
fighting2 = pokes.loc[pokes['Type 2'] == 'Fighting']
psychic2 = pokes.loc[pokes['Type 2'] == 'Psychic']
rock2 = pokes.loc[pokes['Type 2'] == 'Rock']
ghost2 = pokes.loc[pokes['Type 2'] == 'Ghost']
ice2 = pokes.loc[pokes['Type 2'] == 'Ice']
dragon2 = pokes.loc[pokes['Type 2'] == 'Dragon']
dark2 = pokes.loc[pokes['Type 2'] == 'Dark']
steel2 = pokes.loc[pokes['Type 2'] == 'Steel']
flying2 = pokes.loc[pokes['Type 2'] == 'Flying']
